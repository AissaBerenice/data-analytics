# %% [markdown]
# ### Predictive Analysis Introduction

# %%
from sklearn.datasets import make_regression

X,y = make_regression(n_features=1, noise = 40, random_state= 0)

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
import pandas as pd
df = pd.DataFrame(X)
df.columns = ["x"]
df["y"] = y
df
# Out:
#            x          y
# 0  -0.359553 -34.104016
# 1   0.976639 -38.826925
# 2   0.402342  -4.932782
# 3  -0.813146  38.028570
# 4  -0.887786 -29.914813
# ..       ...        ...
# 95 -1.165150 -45.612093
# 96 -0.362741  44.253909
# 97  0.356366   1.823554
# 98 -1.613898  -5.841772
# 99 -1.180632 -71.555049
#
# [100 rows x 2 columns]

# %%
df["x"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Podemos hacer modelos predictivos sacando el promedio de valores de y
import numpy as np
y_mean = np.array([y.mean()]*100)
y_mean
# Out:
# array([-0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
#        -0.66577191, -0.66577191, -0.66577191, -0.66577191, -0.66577191,
# ...

# %%
from sklearn.linear_model import LinearRegression

#model fit es donde entrenamos a un modelo, necesita datos para entrenarse
model1 = LinearRegression()
model2 = LinearRegression()
model2 = LinearRegression()

#el modelo entiende el comportamiento de y en los valores de x reconociendo patrones y poder predecir

model1.fit(X,y)
# Out:
# LinearRegression()

# %%
#Para pedirle al modelo que creamos que prediga algo, 
y_pred = model1.predict(X)

# %%
import matplotlib.pyplot as plt

X,y = make_regression(n_features=1, noise = 40, random_state= 0)

#Selector
plt.figure(figsize= (10, 5))

#Data
plt.scatter(X,y, label = "Random Data")
plt.plot(X,y, )

#Show
plt.xlabel("Features (x)")
plt.ylabel("Target(y)")
plt.title("Scatter Example Plot")
plt.legend()

plt.savefig("../reports/figures/random1.svg")

# %% [markdown]
# # Actividad
#     Dataset: Boston Housing
#     X: Top 1 correlate feature with target
#     Target: MEDV
#     Model: Lineal Regression
#     Send Figure with your name in the title

# %%
df = pd.read_csv("../data/raw/BostonHousing.csv")
df
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

housingdata = pd.read_csv("../data/raw/BostonHousing.csv")

X= np.array(df['lstat']).reshape(-1,1)
y= np.array(df['medv']).reshape(-1,1)

modelo=LinearRegression()
modelo.fit(X,y)
y_pred2=modelo.predict(X)

# %%
plt.figure(figsize=(10,4))

# Data
plt.scatter(X,y, label='Data')

plt.plot(X, y_pred2, label='Linear Regression',c='green')

plt.xlabel('lstat')
plt.ylabel('medv')
plt.title('Clara Aguilar Casillas')
# Out:
# Text(0.5, 1.0, 'Clara Aguilar Casillas')

# %%
# Selector
plt.figure(figsize=(10, 4))

# Data
plt.scatter(X, y, label = "Housing Data")

# Linear Regression
plt.plot(X, y_pred2, label = "Linear Regression", c="red")

# Show
plt.xlabel("Features (x)")
plt.ylabel("Target (y)")
plt.title("Scatter Example Plot")
plt.legend()
plt.savefig("../reports/figures/random1.svg")
