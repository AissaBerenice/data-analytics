# %% [markdown]
# ### Pandas Visualización Titanic
#  **Programacion para Analisis de Datos**
#
#  752224 Aissa Berenice Gonzáles Fosado 02/16/2024
#   ***
#
# Individual, usa el dataset del Titanic, desarrolla un notebook con lo siguiente:
#
# - Crea un histograma por cada features del dataset
# - Separa los datos por clases
# - Utiliza diferentes variantes de histogramas
# - Escribe un hallazgo por cada gráfica resultante

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path = r"C:\Users\Aissa\apps\iteso\data_analytics\data\raw\tested.csv"
df = pd.read_csv(path)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
columna = plt.subplot(2,4,i)
for i in columna:
    plt.figure(figsize=(8, 6))
    df[columna].hist(bins=20, color='cornflowerblue', edgecolor='black')
    plt.title(f'Histograma de {columna}')
    plt.xlabel(columna)
    plt.ylabel('Cantidad')
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 columna = plt.subplot(2,4,i)
#       2 for i in columna:
#       3     plt.figure(figsize=(8, 6))
#
# File c:\Users\Aissa\anaconda3\envs\ITESO\lib\site-packages\matplotlib\pyplot.py:1425, in subplot(*args, **kwargs)
#    1422 fig = gcf()
#    1424 # First, search for an existing subplot with a matching spec.
# -> 1425 key = SubplotSpec._from_subplot_args(fig, args)
#    1427 for ax in fig.axes:
#    1428     # If we found an Axes at the position, we can re-use it if the user passed no
#    1429     # kwargs or if the axes class and kwargs are identical.
#    1430     if (ax.get_subplotspec() == key
#    1431         and (kwargs == {}
#    1432              or (ax._projection_init
#    1433                  == fig._process_projection_requirements(**kwargs)))):
#
# ...

# %%
#define number of subplots
fig,axis = plt.subplots(1, 12)

#create histogram for each column in DataFrame
df.hist(ax=axis)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 5
#       2 fig,axis = plt.subplots(1, 12)
#       4 #create histogram for each column in DataFrame
# ----> 5 df.hist(ax=axis)
#
# File c:\Users\Aissa\anaconda3\envs\ITESO\lib\site-packages\pandas\plotting\_core.py:247, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     160 """
#     161 Make a histogram of the DataFrame's columns.
#     162
#    (...)
#     244     >>> hist = df.hist(bins=3)
#     245 """
#     246 plot_backend = _get_plot_backend(backend)
# --> 247 return plot_backend.hist_frame(
#     248     data,
#     249     column=column,
#     250     by=by,
#     251     grid=grid,
#     252     xlabelsize=xlabelsize,
#     253     xrot=xrot,
#     254     ylabelsize=ylabelsize,
#     255     yrot=yrot,
# ...

# %%
#Separacion de los datos por clases

clase1 = df[(df["Pclass"] == 1)]
clase2 = df[(df["Pclass"] == 2)]
clase3 = df[(df["Pclass"] == 3)]

#Representacion Grafica de Clases

categories = ['Primera Clase', 'Segunda Clase', 'Tercera Clase']
values = [len(clase1), len(clase2), len(clase3)]

plt.pie(values, labels=categories, autopct='%1.1f%%', startangle= 90)
plt.axis('equal') 
plt.title('Pie Chart Example')
plt.show()

# %% [markdown]
# ### Hallazgo de Grafica
# En esta primer grafica pude encontrar que mas la mitad de los pasajerons iban en tercera clase, mientras que iban partes iguales en la primer y segunda clase

# %%
#Histograma de la clase de los pasajerons

columna = 'Pclass'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=3, color='lightsteelblue', edgecolor='black')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks([1, 2, 3], ['Primera', 'Segunda', 'Tercera'])
plt.grid(True)
plt.show()

#Histograma de pasajeros que sobrevivieron

columna = 'Survived'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=[-0.5, 0.5, 1.5], color='steelblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['No', 'Sí'])
plt.grid(True)
plt.show()

#Histograma del sexo de los pasajeros

columna = 'Sex'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=[-0.5, 0.5, 1.5], color='royalblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks(['male', 'female'])
plt.grid(True)
plt.show()

#Histograma de la edad de los pasajerons

columna = 'Age'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=20, color='cornflowerblue', edgecolor='black')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.grid(True)
plt.show()

#Histograma de pasajeros con hermanos abordo

columna = 'SibSp'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=[-0.5, 0.5, 1.5], color='cadetblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Candidad')
plt.xticks([0, 1], ['No', 'Sí'])
plt.grid(True)
plt.show()

#Histograma de pasajeros con padres abordo

columna = 'Parch'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=[-0.5, 0.5, 1.5], color='lightblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Candidad')
plt.xticks([0, 1], ['No', 'Sí'])
plt.grid(True)
plt.show()

#Histograma del costo de su boleto

columna = 'Fare'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=20, color='cornflowerblue', edgecolor='black')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Costo')
plt.grid(True)
plt.show()

#Puerto en que embarcaron los pasajeros (C = Cherbourg; Q = Queenstown; S = Southampton)

columna = 'Embarked'

plt.figure(figsize=(8, 6))
df[columna].hist(bins=3, color='lightskyblue', edgecolor='black')
plt.title(f'Histograma de {columna}')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks(['C', 'Q', 'S'], ['Cherbourg', 'Queenstown', 'Southampton'])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Hallazgos
#
# - Clase: Para la primer grafica, vimos una nueva representacion de el pie chart, en esta si se puede cuantificar cuantos pasajeros iban en cual clase, lo que podria ser muy util para extraer informacion.
#
# - Supervivencia: Para este histograma, se pueden ver cuantos pasajeros sobrevivieron y las cantidades, encontre que dos terceras partes no sobrevivieron.
#
# - Sexo: Este Histograma, representa cuantos hombres y mujeres viajaban, la mayoria fueron hombres
#
# - Edades: Con este grafico note que la mayor concentracion de edades estaba entre 20 y 30 anos
#
# - Hermanos a bordo: Arriba de 100 personas viajaban con hermanos a bordo.
#
# - Padre a bordo: Arriba de 50 personas viajaban con hermanos a bordo.
#
# - Costo del boleto: El rango de los costos fue de a=hasta 500 dolares, con la mayoria debajo de los 100 dolares
#
# - Embarcacion: Para estos datos, (C = Cherbourg; Q = Queenstown; S = Southampton), y el puerto en que mas embarcaron fue en Southhampton

# %%
#Variantes Adicionales

#Histogramas de supervivencia por clases
columna = 'Survived'

plt.figure(figsize=(8, 6))
clase1[columna].hist(bins=[-0.5, 0.5, 1.5], color='steelblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna} pasajeros de Primera Clase')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['No', 'Sí'])
plt.grid(True)
plt.show()

#Histogramas de supervivencia por clases
columna = 'Survived'

plt.figure(figsize=(8, 6))
clase2[columna].hist(bins=[-0.5, 0.5, 1.5], color='steelblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna} pasajeros de Segunda Clase')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['No', 'Sí'])
plt.grid(True)
plt.show()

#Histogramas de supervivencia por clases
columna = 'Survived'

plt.figure(figsize=(8, 6))
clase2[columna].hist(bins=[-0.5, 0.5, 1.5], color='steelblue', edgecolor='black', align='mid')
plt.title(f'Histograma de {columna} pasajeros de Tercera Clase')
plt.xlabel(columna)
plt.ylabel('Cantidad')
plt.xticks([0, 1], ['No', 'Sí'])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Hallazgos
#
# - Primera Clase: Aqui pudimos notar que los pasajeros que viajaban en primera clase, tuvieron una mayor cantidad de sobrevivientes que otras, casi la mitad de las personas lograron sobrevivir.
#
# - Segunda Clase: Dos Terceras Partes de estos pasajeros, no sobrevivieron
#
# - Tercera Clase: Tuvimos resultados similares a la egunda clase
